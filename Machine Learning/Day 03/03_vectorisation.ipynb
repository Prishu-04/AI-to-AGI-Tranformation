# %% [markdown]
# # 03_Vectorisation

# %%
import numpy as np

# %%
employees = np.array([
    [25000, 1, 3],
    [45000, 3, 4],
    [80000, 6, 5],
    [120000, 8, 5],
    [35000, 2, 2]
])

# %% [markdown]
# ## Task 1
# Sacle salary by 100000

# %%
scaled_emp=employees[0]/100
print(scaled_emp)
# Out:
# [2.5e+02 1.0e-02 3.0e-02]

# %% [markdown]
# ## Task 2
# Scale experience by 10

# %%
scaled_exp=employees[1]/10
print(scaled_exp)
# Out:
# [4.5e+03 3.0e-01 4.0e-01]

# %% [markdown]
# ## Task 3
# Scale rating 5

# %% [markdown]
# # ML pipeline

# %%
# !pip install numpy pandas matplotlib seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ml_pipeline = [
    "Problem Statement",
    "Data Collection",
    "Data Understanding",
    "Data Cleaning",
    "Feature Engineering",
    "Encoding",
    "Scaling",
    "Train-Test Split",
    "Model Selection",
    "Model Training",
    "Model Evaluation",
    "Error Analysis",
    "Model Improvement",
    "Deployment",
    "Monitoring",
    "Retraining"
]

for step_number, step in enumerate(ml_pipeline, start=1):
    print(f"{step_number}. {step}")
# Out:
# 1. Problem Statement
# 2. Data Collection
# 3. Data Understanding
# 4. Data Cleaning
# 5. Feature Engineering
# 6. Encoding
# 7. Scaling
# 8. Train-Test Split
# 9. Model Selection
# 10. Model Training
# 11. Model Evaluation
# 12. Error Analysis
# 13. Model Improvement
# 14. Deployment
# 15. Monitoring
# 16. Retraining

# %% [markdown]
# ## Dictionary based Pipeline

# %%
placement_pipeline = {
    "problem": "Predict whether a student is placement-ready",
    "ml_type": "Supervised Learning",
    "problem_type": "Classification",
    "features": [
        "cgpa",
        "dsa_score",
        "projects",
        "internship",
        "communication_score"
    ],
    "label": "placement_ready",
    "models_to_try": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest"
    ],
    "deployment": "Streamlit dashboard or FastAPI API",
    "monitoring": [
        "missing input values",
        "prediction distribution",
        "model accuracy over time"
    ]
}

for key, value in placement_pipeline.items():
    print(key, ":", value)
# Out:
# problem : Predict whether a student is placement-ready
# ml_type : Supervised Learning
# problem_type : Classification
# features : ['cgpa', 'dsa_score', 'projects', 'internship', 'communication_score']
# label : placement_ready
# models_to_try : ['Logistic Regression', 'Decision Tree', 'Random Forest']
# deployment : Streamlit dashboard or FastAPI API
# monitoring : ['missing input values', 'prediction distribution', 'model accuracy over time']

# %% [markdown]
# # ML Workflow Overview

# %% [markdown]
# ## ML WorkFlow

# %%
# !pip install numpy pandas matplotlib seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 1 Dataset

# %%
data={
     "area": [1000,1500,2000],
     "bedrooms":[2,3,4],
     "location":['Patna','Bhubaneswar','Banglore'],
     "price":[4500000,7000000,15000000]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#    area  bedrooms     location     price
# 0  1000         2        Patna   4500000
# 1  1500         3  Bhubaneswar   7000000
# 2  2000         4     Banglore  15000000

# %% [markdown]
# ### Step 2: Features and Targets

# %%
x = df[["area", "bedrooms", "age", "location_score"]]
y = df["price"]

# %%
x
# Out:
#    area  bedrooms  age  location_score
# 0  1200         2    5               8
# 1  1500         3    3               9
# 2   900         2   10               6

# %%
y
# Out:
# 0    6500000
# 1    8500000
# 2    4200000
# Name: price, dtype: int64

# %% [markdown]
# ## Train-Test Split

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Coding Task

# %%
# Traditional programming example

def pass_or_fail(marks):
    if marks >= 33:
        return "Pass"
    return "Fail"

print(pass_or_fail(75))
print(pass_or_fail(20))
# Out:
# Pass
# Fail

# %%
# Machine learning style thinking

students = [
    {"study_hours": 8, "attendance": 90, "result": "Pass"},
    {"study_hours": 2, "attendance": 40, "result": "Fail"},
    {"study_hours": 6, "attendance": 80, "result": "Pass"},
    {"study_hours": 1, "attendance": 30, "result": "Fail"}
]

for student in students:
    print(student)
# Out:
# {'study_hours': 8, 'attendance': 90, 'result': 'Pass'}
# {'study_hours': 2, 'attendance': 40, 'result': 'Fail'}
# {'study_hours': 6, 'attendance': 80, 'result': 'Pass'}
# {'study_hours': 1, 'attendance': 30, 'result': 'Fail'}

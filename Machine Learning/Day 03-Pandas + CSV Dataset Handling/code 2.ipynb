# %% [markdown]
# # Reading CSV Files + Dataset Exploration

# %%
import pandas as pd

# %% [markdown]
# ## Reading CSV file using Pandas

# %%
df1=pd.read_csv("Student_performance.csv")
df1
# Out:
#    Student_ID       Name  Math  Science  English  Attendance  Study_Hours
# 0           1  Pratyaksh    85       88       78          92            5
# 1           2      Rahul    70       75       80          85            3
# 2           3      Sneha    90       95       92          96            6
# 3           4       Aman    95       92       88          90            7
# 4           5      Priya    60       75       80          80            4
# 5           6      Rohit    45       55       50          70            2
# 6           7       Neha    88       84       90          94            5
# 7           8      Karan    35       40       45          60            1

# %% [markdown]
# ## Display First Rows using head()

# %%
df1.head()
# Out:
#    Student_ID       Name  Math  Science  English  Attendance  Study_Hours
# 0           1  Pratyaksh    85       88       78          92            5
# 1           2      Rahul    70       75       80          85            3
# 2           3      Sneha    90       95       92          96            6
# 3           4       Aman    95       92       88          90            7
# 4           5      Priya    60       75       80          80            4

# %% [markdown]
# ## Display Last Rows using tail()

# %%
df1.tail()
# Out:
#    Student_ID   Name  Math  Science  English  Attendance  Study_Hours
# 3           4   Aman    95       92       88          90            7
# 4           5  Priya    60       75       80          80            4
# 5           6  Rohit    45       55       50          70            2
# 6           7   Neha    88       84       90          94            5
# 7           8  Karan    35       40       45          60            1

# %% [markdown]
# ## Checking Shape

# %%
print(df1.shape)
# Out:
# (8, 7)

# %% [markdown]
# ## Checking Columns

# %%
df1.columns
# Out:
# Index(['Student_ID', 'Name', 'Math', 'Science', 'English', 'Attendance',
#        'Study_Hours'],
#       dtype='str')

# %%
print(list(df1.columns))
# Out:
# ['Student_ID', 'Name', 'Math', 'Science', 'English', 'Attendance', 'Study_Hours']

# %% [markdown]
# ## 11. Checking Dataset Information using info()

# %%
print(df1.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Student_ID   8 non-null      int64
#  1   Name         8 non-null      str
#  2   Math         8 non-null      int64
#  3   Science      8 non-null      int64
#  4   English      8 non-null      int64
#  5   Attendance   8 non-null      int64
#  6   Study_Hours  8 non-null      int64
# dtypes: int64(6), str(1)
# memory usage: 580.0 bytes
# None

# %% [markdown]
# ## Checking Statistical Summary using describe()

# %%
df1.describe()
# Out:
#        Student_ID       Math    Science    English  Attendance  Study_Hours
# count     8.00000   8.000000   8.000000   8.000000    8.000000      8.00000
# mean      4.50000  71.000000  75.500000  75.375000   83.375000      4.12500
# std       2.44949  22.411732  19.131126  17.991565   12.704752      2.03101
# min       1.00000  35.000000  40.000000  45.000000   60.000000      1.00000
# 25%       2.75000  56.250000  70.000000  71.000000   77.500000      2.75000
# 50%       4.50000  77.500000  79.500000  80.000000   87.500000      4.50000
# 75%       6.25000  88.500000  89.000000  88.500000   92.500000      5.25000
# max       8.00000  95.000000  95.000000  92.000000   96.000000      7.00000

# %% [markdown]
# ## 13. Checking Data Types

# %%
print(df1.dtypes)
# Out:
# Student_ID     int64
# Name             str
# Math           int64
# Science        int64
# English        int64
# Attendance     int64
# Study_Hours    int64
# dtype: object

# %% [markdown]
# ## Checking Missing VAlues

# %%
df1.isnull()
# Out:
#    Student_ID   Name   Math  Science  English  Attendance  Study_Hours
# 0       False  False  False    False    False       False        False
# 1       False  False  False    False    False       False        False
# 2       False  False  False    False    False       False        False
# 3       False  False  False    False    False       False        False
# 4       False  False  False    False    False       False        False
# 5       False  False  False    False    False       False        False
# 6       False  False  False    False    False       False        False
# 7       False  False  False    False    False       False        False

# %%
print(df1.isnull().sum())
# Out:
# Student_ID     0
# Name           0
# Math           0
# Science        0
# English        0
# Attendance     0
# Study_Hours    0
# dtype: int64

# %% [markdown]
# ## Creating Total and Average Columns

# %%
df1["Total"] = df1["Math"] + df1["Science"] + df1["English"]
df1["Average"] = df1["Total"] / 3
df1["Average"] = df1["Average"].round(2)
df1
# Out:
#    Student_ID       Name  Math  Science  English  Attendance  Study_Hours  \
# 0           1  Pratyaksh    85       88       78          92            5
# 1           2      Rahul    70       75       80          85            3
# 2           3      Sneha    90       95       92          96            6
# 3           4       Aman    95       92       88          90            7
# 4           5      Priya    60       75       80          80            4
# 5           6      Rohit    45       55       50          70            2
# 6           7       Neha    88       84       90          94            5
# 7           8      Karan    35       40       45          60            1
#
#    Total  Average
# 0    251    83.67
# 1    225    75.00
# 2    277    92.33
# 3    275    91.67
# 4    215    71.67
# 5    150    50.00
# 6    262    87.33
# 7    120    40.00

# %% [markdown]
# ## Save Update DataFrame to CSV

# %%
df1.to_csv("student_performance_updated.csv", index=False)

# %% [markdown]
# ## Common Errors

# %% [markdown]
# ### Error 1

# %%
df = pd.read_csv("students.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df = pd.read_csv("students.csv")
#
# File c:\Users\KIIT\AI-to-AGI-Tranformation\Machine Learning\Day 03-Pandas + CSV Dataset Handling\venv3\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %% [markdown]
# ### Error :

# %%
df["math"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df["math"]
#
# NameError: name 'df' is not defined

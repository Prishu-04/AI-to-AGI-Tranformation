# %% [markdown]
# # Multiple Linear Regression + Feature Impact

# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
     "student":['A','B'],
     "study_hours":[8,8],
     "attendance":[90,45],
     "previous_score":[85,40],
     "final_marks":[90,55]
}
df=pd.DataFrame(data)
df
# Out:
#   student  study_hours  attendance  previous_score  final_marks
# 0       A            8          90              85           90
# 1       B            8          45              40           55

# %%
data={
     
}

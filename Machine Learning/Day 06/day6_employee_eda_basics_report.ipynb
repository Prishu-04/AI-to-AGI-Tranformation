# %% [markdown]
# # day6_employee_eda_basics_report

# %%
# !pip install pandas numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Dataset:

# %%
data = {
    "employee_id": [101, 102, 103, 104, 105, 106, 107, 108],
    "name": ["Amit", "Riya", "Karan", "Neha", "Vikas", "Anjali", "Rohit", "Priya"],
    "salary": [25000, 45000, 80000, 120000, 35000, 70000, 30000, 95000],
    "experience": [1, 3, 6, 8, 2, 5, 1, 7],
    "rating": [3, 4, 5, 5, 2, 4, 3, 5],
    "department": ["HR", "IT", "AI", "AI", "SALES", "DATA", "IT", "DATA"],
    "level": ["Junior", "Mid-Level", "Senior", "Senior", "Junior", "Senior", "Junior", "Senior"]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#    employee_id    name  salary  experience  rating department      level
# 0          101    Amit   25000           1       3         HR     Junior
# 1          102    Riya   45000           3       4         IT  Mid-Level
# 2          103   Karan   80000           6       5         AI     Senior
# 3          104    Neha  120000           8       5         AI     Senior
# 4          105   Vikas   35000           2       2      SALES     Junior
# 5          106  Anjali   70000           5       4       DATA     Senior
# 6          107   Rohit   30000           1       3         IT     Junior
# 7          108   Priya   95000           7       5       DATA     Senior

# %% [markdown]
# ## task 1 Print first 5 rows

# %%
df.head()
# Out:
#    employee_id   name  salary  experience  rating department      level
# 0          101   Amit   25000           1       3         HR     Junior
# 1          102   Riya   45000           3       4         IT  Mid-Level
# 2          103  Karan   80000           6       5         AI     Senior
# 3          104   Neha  120000           8       5         AI     Senior
# 4          105  Vikas   35000           2       2      SALES     Junior

# %% [markdown]
# ## Task 2 Print shape

# %%
print(df.shape)
# Out:
# (8, 7)

# %% [markdown]
# ## Task 3 Print columns

# %%
print(df.columns)
# Out:
# Index(['employee_id', 'name', 'salary', 'experience', 'rating', 'department',
#        'level'],
#       dtype='str')

# %% [markdown]
# ## Task 4 Print Data types

# %%
print(df.dtypes)
# Out:
# employee_id    int64
# name             str
# salary         int64
# experience     int64
# rating         int64
# department       str
# level            str
# dtype: object

# %% [markdown]
# ## Task 5 Print Info

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   employee_id  8 non-null      int64
#  1   name         8 non-null      str
#  2   salary       8 non-null      int64
#  3   experience   8 non-null      int64
#  4   rating       8 non-null      int64
#  5   department   8 non-null      str
#  6   level        8 non-null      str
# dtypes: int64(4), str(3)
# memory usage: 580.0 bytes
# None

# %% [markdown]
# ## Task 6 Print Describe

# %%
print(df.describe())
# Out:
#        employee_id         salary  experience    rating
# count      8.00000       8.000000    8.000000  8.000000
# mean     104.50000   62500.000000    4.125000  3.875000
# std        2.44949   34330.328116    2.748376  1.125992
# min      101.00000   25000.000000    1.000000  2.000000
# 25%      102.75000   33750.000000    1.750000  3.000000
# 50%      104.50000   57500.000000    4.000000  4.000000
# 75%      106.25000   83750.000000    6.250000  5.000000
# max      108.00000  120000.000000    8.000000  5.000000

# %% [markdown]
# ## task 7 Check missing values

# %%
print(df.isnull())
# Out:
#    employee_id   name  salary  experience  rating  department  level
# 0        False  False   False       False   False       False  False
# 1        False  False   False       False   False       False  False
# 2        False  False   False       False   False       False  False
# 3        False  False   False       False   False       False  False
# 4        False  False   False       False   False       False  False
# 5        False  False   False       False   False       False  False
# 6        False  False   False       False   False       False  False
# 7        False  False   False       False   False       False  False

# %%
df.isnull().sum()
# Out:
# employee_id    0
# name           0
# salary         0
# experience     0
# rating         0
# department     0
# level          0
# dtype: int64

# %% [markdown]
# ## Task 8. Count departments

# %%
print(df["department"].value_counts())
# Out:
# department
# IT       2
# AI       2
# DATA     2
# HR       1
# SALES    1
# Name: count, dtype: int64

# %% [markdown]
# ## Task 9. Count levels

# %%
print(df["level"].value_counts())
# Out:
# level
# Senior       4
# Junior       3
# Mid-Level    1
# Name: count, dtype: int64

# %% [markdown]
# ## Task 10. Calculate average salary

# %%
print(df["salary"].mean().round(2))
# Out:
# 62500.0

# %% [markdown]
# ## Task 11. Calculate highest salary

# %%
print(df["salary"].max())
# Out:
# 120000

# %% [markdown]
# ## Task 12. Calculate average salary by department

# %%
print(df.groupby("department")["salary"].mean())
# Out:
# department
# AI       100000.0
# DATA      82500.0
# HR        25000.0
# IT        37500.0
# SALES     35000.0
# Name: salary, dtype: float64

# %% [markdown]
# ## Task 13. Calculate average rating by level

# %%
print(df.groupby("level")["rating"].mean())
# Out:
# level
# Junior       2.666667
# Mid-Level    4.000000
# Senior       4.750000
# Name: rating, dtype: float64

# %% [markdown]
# ## Task 14. Print Correlation between salary, experience and rating

# %%
print(df[["salary","experience","rating"]].corr())
# Out:
#               salary  experience    rating
# salary      1.000000    0.987935  0.859235
# experience  0.987935    1.000000  0.882860
# rating      0.859235    0.882860  1.000000

# %% [markdown]
# ## Task 15 Save to CSV

# %%
df.to_csv("day6_employee_eda_basics_report.csv",index=False)

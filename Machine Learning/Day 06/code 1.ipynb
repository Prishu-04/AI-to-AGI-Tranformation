# %% [markdown]
# # Exploratory Data Analysis Basics

# %%
# !pip install pandas numpy
# Out:
# Requirement already satisfied: pandas in .\venv6\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy in .\venv6\Lib\site-packages (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv6\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\venv6\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in .\venv6\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Dataset

# %%
data = {
    "student_id": [101, 102, 103, 104, 105, 106, 107, 108],
    "name": ["Rahul", "Aman", "Priya", "Sneha", "Karan", "Anjali", "Rohit", "Neha"],
    "marks": [85, 72, 45, 91, 60, 88, 35, 67],
    "attendance": [90, 80, 70, 95, 78, 92, 60, 82],
    "study_hours": [5, 4, 3, 6, 2, 5, 1, 4],
    "subject": ["AI", "DATA", "AI", "AI", "DATA", "DATA", "WEB", "WEB"],
    "result": ["Excellent", "Good", "Needs Improvement", "Excellent", "Good", "Excellent", "Needs Improvement", "Good"]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#    student_id    name  marks  attendance  study_hours subject  \
# 0         101   Rahul     85          90            5      AI
# 1         102    Aman     72          80            4    DATA
# 2         103   Priya     45          70            3      AI
# 3         104   Sneha     91          95            6      AI
# 4         105   Karan     60          78            2    DATA
# 5         106  Anjali     88          92            5    DATA
# 6         107   Rohit     35          60            1     WEB
# 7         108    Neha     67          82            4     WEB
#
#               result
# 0          Excellent
# 1               Good
# 2  Needs Improvement
# 3          Excellent
# 4               Good
# 5          Excellent
# 6  Needs Improvement
# 7               Good

# %% [markdown]
# ## First look at Data

# %%
df.head()
# Out:
#    student_id   name  marks  attendance  study_hours subject  \
# 0         101  Rahul     85          90            5      AI
# 1         102   Aman     72          80            4    DATA
# 2         103  Priya     45          70            3      AI
# 3         104  Sneha     91          95            6      AI
# 4         105  Karan     60          78            2    DATA
#
#               result
# 0          Excellent
# 1               Good
# 2  Needs Improvement
# 3          Excellent
# 4               Good

# %%
print(df.columns)
# Out:
# Index(['student_id', 'name', 'marks', 'attendance', 'study_hours', 'subject',
#        'result'],
#       dtype='str')

# %%
print(df.shape)
# Out:
# (8, 7)

# %%
print(df.dtypes)
# Out:
# student_id     int64
# name             str
# marks          int64
# attendance     int64
# study_hours    int64
# subject          str
# result           str
# dtype: object

# %% [markdown]
# ## Dataset Info

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   8 non-null      int64
#  1   name         8 non-null      str
#  2   marks        8 non-null      int64
#  3   attendance   8 non-null      int64
#  4   study_hours  8 non-null      int64
#  5   subject      8 non-null      str
#  6   result       8 non-null      str
# dtypes: int64(4), str(3)
# memory usage: 580.0 bytes

# %% [markdown]
# ## Statistical Summary

# %%
print(df.describe().round(2))
# Out:
#        student_id  marks  attendance  study_hours
# count        8.00   8.00        8.00         8.00
# mean       104.50  67.88       80.88         3.75
# std          2.45  20.41       11.78         1.67
# min        101.00  35.00       60.00         1.00
# 25%        102.75  56.25       76.00         2.75
# 50%        104.50  69.50       81.00         4.00
# 75%        106.25  85.75       90.50         5.00
# max        108.00  91.00       95.00         6.00

# %% [markdown]
# ## Category Counts

# %%
print(df["result"].value_counts())
# Out:
# result
# Excellent            3
# Good                 3
# Needs Improvement    2
# Name: count, dtype: int64

# %% [markdown]
# ## Basic Analysis

# %%
print("Average marks:", df["marks"].mean())
print("Highest marks:", df["marks"].max())
print("Lowest marks:", df["marks"].min())

print("Average attendance:", df["attendance"].mean())
print("Average study hours:", df["study_hours"].mean())
# Out:
# Average marks: 67.875
# Highest marks: 91
# Lowest marks: 35
# Average attendance: 80.875
# Average study hours: 3.75

# %% [markdown]
# ## Group based Analysis

# %%
print(df.groupby("subject")["marks"].mean().round(3))
# Out:
# subject
# AI      73.667
# DATA    73.333
# WEB     51.000
# Name: marks, dtype: float64

# %%
print(df.groupby("result")["attendance"].mean())
# Out:
# result
# Excellent            92.333333
# Good                 80.000000
# Needs Improvement    65.000000
# Name: attendance, dtype: float64

# %% [markdown]
# ## Correlation

# %%
print(df[["marks", "attendance", "study_hours"]].corr())
# Out:
#                 marks  attendance  study_hours
# marks        1.000000    0.986359     0.925602
# attendance   0.986359    1.000000     0.928457
# study_hours  0.925602    0.928457     1.000000
